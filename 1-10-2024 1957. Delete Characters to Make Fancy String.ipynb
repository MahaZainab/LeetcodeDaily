# %% [markdown]
# ## 1957. Delete Characters to Make Fancy String

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Examples:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
