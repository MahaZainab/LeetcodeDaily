# %% [markdown]
# ## 1593. Split a String Into the Max Number of Unique Substrings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Examples:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
