# %% [markdown]
# ## 2463. Minimum Total Distance Traveled

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Examples:

# %% [markdown]
# ![image.png](attachment:image.png)
