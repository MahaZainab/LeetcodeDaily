# %% [markdown]
# ## 2044. Count Number of Maximum Bitwise-OR Subsets

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
